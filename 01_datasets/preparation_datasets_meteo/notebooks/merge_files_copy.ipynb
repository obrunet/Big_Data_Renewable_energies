# %%
import pandas as pd
from os import listdir
from os.path import isfile, isdir, join

# %%
folder_theme = {"CC": "cloud_cover_", "QQ": "global_radiation_", "TX": "max_temp_", "FX": "wind_gust_", \
                "TG": "mean_temp_", "FG": "mean_wind_speed_", "SS": "sunshine_duration_", "DD": "wind_direction_"}

# %%
df= pd.DataFrame()

# %%
current_path = "test_datasets/Daily global radiation QQ "
folders = [f for f in listdir(current_path) if isdir(join(current_path, f))]

# %%
only_files = [f for f in listdir(current_path) if isfile(join(current_path, f))]

# %%
def clean_dataframe(df, col_name):
    """Clean the dataset, remove unneeded columns, NaNs, strange values..."""
    # remove columns full of NaNs, corresponding to several spaces in the txt file
    df = df.dropna(axis=1, how='all')
    # rename them
    df = df.rename(columns={2: "date", 3: col_name})
    # remove comas
    try:
        df[col_name] = df[col_name].str.replace(",", "")
    except:
        pass
    # drop lines with nan
    df = df.dropna()
    # convert type as int
    df[col_name] = df[col_name].astype(int)
    # keep interesting lines & cols
    df = df[df[col_name] != -9999]
    df = df[["date", col_name]]
    # convert into date
    #df.date = df.date.apply(lambda s: s.split(',')[1])
    df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')
    return df

# %%
# initialize an empty DF
df= pd.DataFrame()

for fn in only_files:
    # set column name based on file name
    column_name = folder_theme[fn[:2]] + fn[8:-3]
    # create  and format DF
    df_temp = pd.read_csv(join(current_path, fn), header=None)
    df_temp = clean_dataframe(df_temp, column_name)
    # 1st time copy DF in empty one    
    if df.empty:
        df = df_temp.copy()
    # otherwise merge 2 DF
    else:
        df = pd.merge(df, df_temp, how='outer')

df = df.sort_values(by='date')
df.head()
# Out:
#             date  global_radiation_000029.  global_radiation_000034.  \
# 15220 1964-01-02                       NaN                       NaN
# 15221 1964-01-03                       NaN                       NaN
# 15222 1964-01-04                       NaN                       NaN
# 15223 1964-01-05                       NaN                       NaN
# 15224 1964-01-06                       NaN                       NaN
#
#        global_radiation_000012.  global_radiation_000013.  \
# 15220                      61.0                       NaN
# 15221                      58.0                       NaN
# 15222                      56.0                       NaN
# 15223                      44.0                       NaN
# 15224                      37.0                       NaN
#
#        global_radiation_000014.  global_radiation_000021.  \
# 15220                      41.0                      44.0
# 15221                      68.0                      48.0
# 15222                      70.0                      60.0
# 15223                      70.0                      39.0
# 15224                      22.0                       9.0
#
#        global_radiation_000016.  global_radiation_000032.  \
# 15220                      17.0                       NaN
# 15221                      47.0                       NaN
# 15222                      47.0                       NaN
# 15223                      60.0                       NaN
# 15224                       7.0                       NaN
#
#        global_radiation_000033.  global_radiation_000017.  \
# 15220                       NaN                      48.0
# 15221                       NaN                      44.0
# 15222                       NaN                      18.0
# 15223                       NaN                       9.0
# 15224                       NaN                      21.0
#
#        global_radiation_000028.  global_radiation_000015.
# 15220                       5.0                      87.0
# 15221                       3.0                      88.0
# 15222                      11.0                      90.0
# 15223                      24.0                      91.0
# 15224                       7.0                      91.0

# %%
df.tail()
# Out:
#             date  global_radiation_000029.  global_radiation_000034.  \
# 15216 2019-09-26                       NaN                     108.0
# 15217 2019-09-27                       NaN                     149.0
# 20360 2019-09-28                       NaN                       NaN
# 15218 2019-09-29                       NaN                     184.0
# 15219 2019-09-30                       NaN                     108.0
#
#        global_radiation_000012.  global_radiation_000013.  \
# 15216                       NaN                       NaN
# 15217                       NaN                       NaN
# 20360                       NaN                       NaN
# 15218                       NaN                       NaN
# 15219                       NaN                       NaN
#
#        global_radiation_000014.  global_radiation_000021.  \
# 15216                       NaN                       NaN
# 15217                       NaN                       NaN
# 20360                       NaN                       NaN
# 15218                       NaN                       NaN
# 15219                       NaN                       NaN
#
#        global_radiation_000016.  global_radiation_000032.  \
# 15216                       NaN                      85.0
# 15217                       NaN                     108.0
# 20360                       NaN                       NaN
# 15218                       NaN                     147.0
# 15219                       NaN                      95.0
#
#        global_radiation_000033.  global_radiation_000017.  \
# 15216                     159.0                      10.0
# 15217                     181.0                      19.0
# 20360                       NaN                       9.0
# 15218                     188.0                       5.0
# 15219                     143.0                      15.0
#
#        global_radiation_000028.  global_radiation_000015.
# 15216                       NaN                       NaN
# 15217                       NaN                       NaN
# 20360                       NaN                       NaN
# 15218                       NaN                       NaN
# 15219                       NaN                       NaN
